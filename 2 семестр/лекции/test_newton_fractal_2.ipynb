# %%
include("newton_fractal_2.jl")

fractal = NewtonFractal(basin_colors = (RGB(1,0,0),RGB(0,1,0),RGB(0,0,1)), iterations_number = 50, ε=0.5)
build!(fractal)
file_name = "newton_fractal_50.png"
save(file_name,fractal)

load(file_name)
# Out:
# 4001×4001 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)  …  RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)  …  RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,1.0,0.0)  RGB{N0f8}(0.0,1.0,0.0)     RGB{N0f8}(1.0,0.0,0.0)
#  ⋮                                               ⋱  ⋮
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)  …  RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)     RGB{N0f8}(1.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,1.0)  RGB{N0f8}(0.0,0.0,1.0)  …  RGB{N0f8}(1.0,0.0,0.0)
